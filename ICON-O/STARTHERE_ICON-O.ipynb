# %%
import intake
import xarray as xr
import numpy as np
import matplotlib.pylab as plt
import matplotlib.cm as cm
import cmocean.cm as cmo
from scipy.interpolate import CloughTocher2DInterpolator, LinearNDInterpolator, NearestNDInterpolator
import pandas as pd

# %% [markdown]
# # TLDR

# %% [markdown]
# Get the data

# %%
catalog_file = "/home/k/k203123/NextGEMS_Cycle2.git/experiments/ngc2009/scripts/ngc2009.json"
cat = intake.open_esm_datastore(catalog_file)
final_query = cat.search(realm="oce", frequency='3hour', variable_id='to')
dataset_dict = final_query.to_dataset_dict(
    cdf_kwargs={
        "chunks": dict(
            time=1,
            # height=1,
        )
    }
)
keys = list(dataset_dict.keys())
data = dataset_dict[keys[0]]
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institution_id.source_id.experiment_id.simulation_id.realm.frequency.time_reduction.grid_label.level_type'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %% [markdown]
# Get the grid

# %%
grid_path = "/pool/data/ICON/grids/public/mpim/0016/icon_grid_0016_R02B09_O.nc"
grid = xr.open_dataset(grid_path)
model_lon_icon = grid.clon.values*180./np.pi
model_lat_icon = grid.clat.values*180./np.pi

# %% [markdown]
# Interpolate

# %%
lon = np.linspace(-30, 60, 90*10)
lat = np.linspace(33, 72, (72-33)*10)
lon2, lat2 = np.meshgrid(lon, lat)

points_icon = np.vstack((model_lon_icon, model_lat_icon)).T
data_sample = data.to[0,0,:]

nn_interpolation = NearestNDInterpolator(points_icon, data_sample.values)
interpolated_nn = nn_interpolation((lon2, lat2))

# %% [markdown]
# Plot

# %%
plt.figure(figsize=(15,15))
plt.imshow(np.flipud(interpolated_nn))

# %% [markdown]
# ## Longer version

# %%
catalog_file = "/home/k/k203123/NextGEMS_Cycle2.git/experiments/ngc2009/scripts/ngc2009.json"

# %%
cat = intake.open_esm_datastore(catalog_file)
cat
# Out:
# <p><strong>ICON-ESM catalog with 12 dataset(s) from 16013 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>variable_id</th>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>simulation_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>time_reduction</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>level_type</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>time_min</th>
#       <td>4570</td>
#     </tr>
#     <tr>
#       <th>time_max</th>
#       <td>4626</td>
#     </tr>
#     <tr>
#       <th>grid_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>format</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>uri</th>
#       <td>16013</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
def get_from_cat(catalog, columns):
    if type (columns) == type (""):
        columns = [columns]
    return catalog.df[columns].drop_duplicates().sort_values(columns)

# %%
pd.set_option("max_colwidth", None)
overview = get_from_cat(cat, ["experiment_id", "source_id", "realm", "frequency", "variable_id"])
overview
# Out:
#         experiment_id source_id realm frequency  \
# 4945  nextgems_cycle2  ICON-ESM   atm      1day
# 7789  nextgems_cycle2  ICON-ESM   atm      1day
# 49    nextgems_cycle2  ICON-ESM   atm     2hour
# 145   nextgems_cycle2  ICON-ESM   atm  30minute
# 129   nextgems_cycle2  ICON-ESM   atm  30minute
# 33    nextgems_cycle2  ICON-ESM   atm  30minute
# 17    nextgems_cycle2  ICON-ESM   atm  30minute
# 97    nextgems_cycle2  ICON-ESM   atm     6hour
# 161   nextgems_cycle2  ICON-ESM   atm     6hour
# 81    nextgems_cycle2  ICON-ESM   atm     6hour
# 113   nextgems_cycle2  ICON-ESM   atm     6hour
# 1     nextgems_cycle2  ICON-ESM   atm     6hour
# 65    nextgems_cycle2  ICON-ESM   atm     6hour
# 0     nextgems_cycle2  ICON-ESM   atm     6hour
# 287   nextgems_cycle2  ICON-ESM   oce      1day
# 193   nextgems_cycle2  ICON-ESM   oce      1day
# 240   nextgems_cycle2  ICON-ESM   oce      1day
# 224   nextgems_cycle2  ICON-ESM   oce     1hour
# 208   nextgems_cycle2  ICON-ESM   oce     1hour
# 271   nextgems_cycle2  ICON-ESM   oce     3hour
# 255   nextgems_cycle2  ICON-ESM   oce     3hour
# 177   nextgems_cycle2  ICON-ESM   oce     6hour
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         variable_id
# 4945                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                (clt, evspsbl, tas, ts, rldscs, rlutcs, rsdscs, rsuscs, rsutcs)
# 7789                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           (psl, clt, evspsbl, tas, ts, rldscs, rlutcs, rsdscs, rsuscs, rsutcs)
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         (phalf,)
# 145                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     (hydro_canopy_cond_limited_box, hydro_w_snow_box, hydro_snow_soil_dens_box)
# 129                                                                                                                                                                                                                                                                                                                                                                                                                                                                               (hydro_discharge_ocean_box, hydro_drainage_box, hydro_runoff_box, hydro_transpiration_box, sse_grnd_hflx_old_box)
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  (psl, ps, sit, sic, tas, ts, uas, vas, cfh_lnd)
# 17                                                                                                                                                                                                                                                                                                                                                                                                                      (sfcwind, clivi, cllvi, cptgzvi, hfls, hfss, prlr, pr, prw, qgvi, qrvi, qsvi, rlds, rlus, rlut, rsds, rsdt, rsus, rsut, tauu, tauv, rpds_dir, rpds_dif, rvds_dif, rnds_dif)
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                (clw, cli, pfull)
# 161                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    (hydro_w_soil_sl_box, hydro_w_ice_sl_box, sse_t_soil_sl_box)
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   (ta, hus, rho)
# 113                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          (ta, ua, va, clw, hus, zfull, cli, pv)
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               (tas_gmean, rsdt_gmean, rsut_gmean, rlut_gmean, radtop_gmean, prec_gmean, evap_gmean, fwfoce_gmean)
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     (ua, va, wa)
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             (zghalf, zg, dzghalf)
# 287                                                                                                                                                                                                                                                                                                                                                                  (atlantic_hfbasin, atlantic_hfl, atlantic_moc, atlantic_sltbasin, atlantic_wfl, global_hfbasin, global_hfl, global_moc, global_sltbasin, global_wfl, pacific_hfbasin, pacific_hfl, pacific_moc, pacific_sltbasin, pacific_wfl)
# 193   (atmos_fluxes_FrshFlux_Evaporation, atmos_fluxes_FrshFlux_Precipitation, atmos_fluxes_FrshFlux_Runoff, atmos_fluxes_FrshFlux_SnowFall, atmos_fluxes_HeatFlux_Latent, atmos_fluxes_HeatFlux_LongWave, atmos_fluxes_HeatFlux_Sensible, atmos_fluxes_HeatFlux_ShortWave, atmos_fluxes_HeatFlux_Total, atmos_fluxes_stress_x, atmos_fluxes_stress_xw, atmos_fluxes_stress_y, atmos_fluxes_stress_yw, conc, heat_content_seaice, heat_content_snow, heat_content_total, hi, hs, ice_u, ice_v, mlotst, Qbot, Qtop, sea_level_pressure, stretch_c, zos, verticallyTotal_mass_flux_e, Wind_Speed_10m)
# 240                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     (so, tke, to, u, v, w, A_tracer_v_to, A_veloc_v, heat_content_liquid_water)
# 224                                                                                                                                                                                    (atmos_fluxes_FrshFlux_Evaporation, atmos_fluxes_FrshFlux_Precipitation, atmos_fluxes_FrshFlux_Runoff, atmos_fluxes_FrshFlux_SnowFall, atmos_fluxes_HeatFlux_Latent, atmos_fluxes_HeatFlux_LongWave, atmos_fluxes_HeatFlux_Sensible, atmos_fluxes_HeatFlux_ShortWave, atmos_fluxes_HeatFlux_Total, atmos_fluxes_stress_x, atmos_fluxes_stress_xw, atmos_fluxes_stress_y, atmos_fluxes_stress_yw, Qbot, Qtop)
# 208                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          (so, to, u, v, conc, hi, hs, ice_u, ice_v, mlotst, sea_level_pressure, stretch_c, Wind_Speed_10m, zos)
# 271                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 (A_tracer_v_to, A_veloc_v, tke)
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               (so, to, u, v, w)
# 177              (total_salt, total_saltinseaice, total_saltinliquidwater, amoc26n, kin_energy_global, pot_energy_global, total_energy_global, ssh_global, sst_global, sss_global, potential_enstrophy_global, HeatFlux_Total_global, FrshFlux_Precipitation_global, FrshFlux_SnowFall_global, FrshFlux_Evaporation_global, FrshFlux_Runoff_global, FrshFlux_VolumeIce_global, FrshFlux_TotalOcean_global, FrshFlux_TotalIce_global, FrshFlux_VolumeTotal_global, totalsnowfall_global, ice_volume_nh, ice_volume_sh, ice_extent_nh, ice_extent_sh, global_heat_content, global_heat_content_solid)

# %%
cat.search(realm="oce", frequency='3hour', variable_id='to')
# Out:
# <p><strong>ICON-ESM catalog with 1 dataset(s) from 823 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>variable_id</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>simulation_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_reduction</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>level_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_min</th>
#       <td>823</td>
#     </tr>
#     <tr>
#       <th>time_max</th>
#       <td>823</td>
#     </tr>
#     <tr>
#       <th>grid_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>format</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>uri</th>
#       <td>823</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
final_query = cat.search(realm="oce", frequency='3hour', variable_id='to')

# %%
dataset_dict = final_query.to_dataset_dict(
    cdf_kwargs={
        "chunks": dict(
            time=1,
            # height=1,
        )
    }
)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institution_id.source_id.experiment_id.simulation_id.realm.frequency.time_reduction.grid_label.level_type'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>

# %%
dataset_dict
# Out:
# {'nextGEMS.MPI-M.ICON-ESM.nextgems_cycle2.ngc2009.oce.3hour.inst.gn.ml': <xarray.Dataset>
#  Dimensions:  (time: 6168, depth: 60, ncells: 14886338)
#  Coordinates:
#    * depth    (depth) float64 1.0 3.05 5.2 7.45 9.8 ... 461.5 481.2 501.6 522.6
#    * time     (time) datetime64[ns] 2020-01-20T03:00:00 ... 2022-03-01
#  Dimensions without coordinates: ncells
#  Data variables:
#      to       (time, depth, ncells) float64 dask.array<chunksize=(1, 60, 14886338), meta=np.ndarray>
#  Attributes: (12/13)
#      intake_esm_varname:      ['to']
#      number_of_grid_used:     16
#      title:                   ICON simulation
#      uuidOfHGrid:             375cb0cc-637e-11e8-9d6f-8f41a9b9ff4b
#      grid_file_uri:           http://icon-downloads.mpimet.mpg.de/grids/public...
#      history:                 ./icon at 20220512 152214\n./icon at 20220512 19...
#      ...                      ...
#      comment:                 Sapphire Dyamond (k203123) on l10745 (Linux 4.18...
#      CDI:                     Climate Data Interface version 1.8.3rc (http://m...
#      references:              see MPIM/DWD publications
#      source:                  git@gitlab.dkrz.de:icon/icon-aes.git@87a1eaded69...
#      institution:             Max Planck Institute for Meteorology/Deutscher W...
#      intake_esm_dataset_key:  nextGEMS.MPI-M.ICON-ESM.nextgems_cycle2.ngc2009....}

# %%
keys = list(dataset_dict.keys())
keys
# Out:
# ['nextGEMS.MPI-M.ICON-ESM.nextgems_cycle2.ngc2009.oce.3hour.inst.gn.ml']

# %%
data = dataset_dict[keys[0]]
data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 6168, depth: 60, ncells: 14886338)
# Coordinates:
#   * depth    (depth) float64 1.0 3.05 5.2 7.45 9.8 ... 461.5 481.2 501.6 522.6
#   * time     (time) datetime64[ns] 2020-01-20T03:00:00 ... 2022-03-01
# Dimensions without coordinates: ncells
# Data variables:
#     to       (time, depth, ncells) float64 dask.array<chunksize=(1, 60, 14886338), meta=np.ndarray>
# Attributes: (12/13)
#     intake_esm_varname:      ['to']
#     number_of_grid_used:     16
#     title:                   ICON simulation
#     uuidOfHGrid:             375cb0cc-637e-11e8-9d6f-8f41a9b9ff4b
#     grid_file_uri:           http://icon-downloads.mpimet.mpg.de/grids/public...
#     history:                 ./icon at 20220512 152214\n./icon at 20220512 19...
#     ...                      ...
#     comment:                 Sapphire Dyamond (k203123) on l10745 (Linux 4.18...
#     CDI:                     Climate Data Interface version 1.8.3rc (http://m...
#     references:              see MPIM/DWD publications
#     source:                  git@gitlab.dkrz.de:icon/icon-aes.git@87a1eaded69...
#     institution:             Max Planck Institute for Meteorology/Deutscher W...
#     intake_esm_dataset_key:  nextGEMS.MPI-M.ICON-ESM.nextgems_cycle2.ngc2009....

# %%
data_sample = data.to[0,0,:]

# %%
data_sample
# Out:
# <xarray.DataArray 'to' (ncells: 14886338)>
# dask.array<getitem, shape=(14886338,), dtype=float64, chunksize=(14886338,), chunktype=numpy.ndarray>
# Coordinates:
#     depth    float64 1.0
#     time     datetime64[ns] 2020-01-20T03:00:00
# Dimensions without coordinates: ncells
# Attributes:
#     standard_name:                sea_water_potential_temperature
#     long_name:                    sea water potential temperature
#     units:                        deg C
#     code:                         2
#     CDI_grid_type:                unstructured
#     number_of_grid_in_reference:  1

# %%
data_sample.shape
# Out:
# (14886338,)

# %%
data_sample.values
# Out:
# array([-1.79999697, -1.79997087, -1.79998517, ..., 10.74818325,
#        10.77455997, 10.73970509])

# %%
grid_path = "/pool/data/ICON/grids/public/mpim/0016/icon_grid_0016_R02B09_O.nc"
grid = xr.open_dataset(grid_path)

# %% [markdown]
# Model Grid

# %%
model_lon_icon = grid.clon.values*180./np.pi
model_lat_icon = grid.clat.values*180./np.pi

# %%
model_lon_icon.shape
# Out:
# (14886338,)

# %% [markdown]
# Target grid

# %%
lon = np.linspace(-30, 60, 90*10)
lat = np.linspace(33, 72, (72-33)*10)
lon2, lat2 = np.meshgrid(lon, lat)

# %%
from scipy.interpolate import CloughTocher2DInterpolator, LinearNDInterpolator, NearestNDInterpolator

# %%
points_icon = np.vstack((model_lon_icon, model_lat_icon)).T

# %%
nn_interpolation = NearestNDInterpolator(points_icon, data_sample.values)

# %%
interpolated_nn = nn_interpolation((lon2, lat2))

# %%
plt.figure(figsize=(15,15))
plt.imshow(np.flipud(interpolated_nn))

# %%
plt.figure(figsize=(15,15))
plt.imshow(np.flipud(np.ma.masked_equal(interpolated_nn, 0)))

# %% [markdown]
# ## Find point on the map

# %%
def tunnel_fast1d(latvar, lonvar, lonlat):
    """
    Find closest point in a set of (lat,lon) points to specified pointd.
    Parameters:
    -----------
        latvar : ndarray
            1d array with lats
        lonvar : ndarray
            1d array with lons
        lonlat : ndarray
            2d array with the shape of [2, number_of_point],
            that contain coordinates of the points
    Returns:
    --------
        node : int
            node number of the closest point
    Taken from here http://www.unidata.ucar.edu/blogs/developer/en/entry/accessing_netcdf_data_by_coordinates
    and modifyed for 1d
    """

    rad_factor = np.pi / 180.0  # for trignometry, need angles in radians
    # Read latitude and longitude from file into numpy arrays
    latvals = latvar[:] * rad_factor
    lonvals = lonvar[:] * rad_factor

    # Compute numpy arrays for all values, no loops
    clat, clon = np.cos(latvals), np.cos(lonvals)
    slat, slon = np.sin(latvals), np.sin(lonvals)

    clat_clon = clat * clon
    clat_slon = clat * slon

    lat0_rad = lonlat[1, :] * rad_factor
    lon0_rad = lonlat[0, :] * rad_factor

    delX_pre = np.cos(lat0_rad) * np.cos(lon0_rad)
    delY_pre = np.cos(lat0_rad) * np.sin(lon0_rad)
    delZ_pre = np.sin(lat0_rad)

    nodes = np.zeros((lonlat.shape[1]))
    for i in range(lonlat.shape[1]):
        delX = delX_pre[i] - clat_clon
        delY = delY_pre[i] - clat_slon
        delZ = delZ_pre[i] - slat
        dist_sq = delX ** 2 + delY ** 2 + delZ ** 2
        minindex_1d = dist_sq.argmin()  # 1D index of minimum element
        node = np.unravel_index(minindex_1d, latvals.shape)
        nodes[i] = node[0]

    return nodes.astype('int')

# %%
lon_target = -10
lat_target = 50

# %%
points = np.array([[lat_target],[lon_target]])

# %%
index = tunnel_fast1d(model_lon_icon, model_lat_icon, points)

# %%
model_lon_icon[index[0]]
# Out:
# -10.02962396505484

# %%
model_lat_icon[index[0]]
# Out:
# 49.97659189571888

# %%
data.to
# Out:
# <xarray.DataArray 'to' (time: 6168, depth: 60, ncells: 14886338)>
# dask.array<concatenate, shape=(6168, 60, 14886338), dtype=float64, chunksize=(1, 60, 14886338), chunktype=numpy.ndarray>
# Coordinates:
#   * depth    (depth) float64 1.0 3.05 5.2 7.45 9.8 ... 461.5 481.2 501.6 522.6
#   * time     (time) datetime64[ns] 2020-01-20T03:00:00 ... 2022-03-01
# Dimensions without coordinates: ncells
# Attributes:
#     standard_name:                sea_water_potential_temperature
#     long_name:                    sea water potential temperature
#     units:                        deg C
#     code:                         2
#     CDI_grid_type:                unstructured
#     number_of_grid_in_reference:  1

# %%
data.to[:,0, index[0]]
# Out:
# <xarray.DataArray 'to' (time: 6168)>
# dask.array<getitem, shape=(6168,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     depth    float64 1.0
#   * time     (time) datetime64[ns] 2020-01-20T03:00:00 ... 2022-03-01
# Attributes:
#     standard_name:                sea_water_potential_temperature
#     long_name:                    sea water potential temperature
#     units:                        deg C
#     code:                         2
#     CDI_grid_type:                unstructured
#     number_of_grid_in_reference:  1

# %%
data.to[:100, 0, index[0]].plot()

# %%
data.to.sel(time=slice('2020-01-25','2020-02-15'))[:,0,index[0]].plot()
